# %%
#### READING ONLY ORIGINAL CATEGORIES

f = open('../data/original_categories.txt','r')
mixed_text = f.read()

# %% [markdown]
# ## Read in the Data and PreProcess

# %%
import os
os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Dask
import pandas as pd
import re
import icu
from tqdm import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

# %%
# Data Loading and PreProcessing
import modin.pandas as mpd
import modin.pandas.utils as ut

data_path = os.path.abspath(
    os.path.join(
        os.path.pardir,
        'data',
        'prods.tar.gz'
    )
)

def exclude_unnamed(df):
    matches_to_exclude = re.findall("^'Unnamed[^,]*",str(df.columns.tolist()).strip("[]"))
    m = [str(x).replace('"', '').replace("'","") for x in matches_to_exclude]
    return m

def do_category_pre_processing(source_category="original_categories",\
                               data_path=data_path,\
                              random_n=200):
    from polyglot.detect import Detector
    df = pd.read_csv(data_path)
    if random_n != -1:
        df = df.sample(random_n)
    exclude_these = exclude_unnamed(df)
    df = df.drop(exclude_these,axis=1)
    #df.translation = df.original_categories.apply(return_single_translation)
    tqdm.pandas(desc='PROGRESS>>>') 
    df.loc[:,source_category] = df.loc[:,source_category].astype(str)
    df['poly_obj'] = df.loc[:,source_category].progress_apply(lambda x: Detector(x, quiet=True))
    df['Text-lang'] = df['poly_obj'].progress_apply(lambda x: icu.Locale.getDisplayName(x.language.locale))
    df['confidence'] = df['poly_obj'].progress_apply( lambda x: x.language.confidence)
    df = df.drop(['ean','summary','url','provider','price','brand','./._prods.csv'],axis=1)
    #df = df.loc[:,["name","description","original_categories","internal_tree"]]
    return df

data = do_category_pre_processing()
# data_modin = ut.from_pandas(data) cannot serialise the data right now
# Out:
# PROGRESS>>>: 100%|██████████| 200/200 [00:00<00:00, 5091.04it/s]
#
#
# PROGRESS>>>: 100%|██████████| 200/200 [00:00<00:00, 23142.90it/s]
#
#
# PROGRESS>>>: 100%|██████████| 200/200 [00:00<00:00, 69516.93it/s]

# %% [markdown]
# ### Then Make the Translation work on Pandas Dataframe

# %%
data.head()
# Out:
#                                                      name  \
# 691466                   Leggings Leggingsit Musta Lindex
# 652860  Polo Shirts Lyhythihainen Poolopaita Harmaa Es...
# 51738                                   Womens Ultra Flex
# 475617  Iron Gym® Exercise & Yoga Mat With Carry Strap...
# 592884       Happy Holly Ida Suede Look Skirt Beige 40/42
#
#                                               description  \
# 691466                                            Lindex.
# 652860                          Esprit Casual Polo Shirts
# 51738                          Skechers Womens Ultra Flex
# 475617  Iron Gym® Exercise & Yoga Mat with Carry Strap...
# 592884  HAPPY HOLLY tyylikäs kynähame mokkajäljitelmää...
#
#                                original_categories  \
# 691466                               Kids|Leggings
# 652860                                   Men|Polos
# 51738                                  Women|Shoes
# 475617  Varusteet & Tarvikkeet|Välineet|Joogamatot
# 592884                  Vaatteet|Hameet|Midihameet
#
#                                             internal_tree          brand  \
# 691466                       Children | Vaatteet | Housut         Lindex
# 652860      Fashion | Vaatteet | Miehet | Paidat | Poolot  Esprit Casual
# 51738                           Fashion | Kengät | Naiset       Skechers
# 475617       Fitness | Treenivarusteet | Jooga ja pilates       Iron Gym
# 592884  Fashion | Vaatteet | Naiset | Hameet | Midihameet    Happy Holly
#
#                                                  poly_obj Text-lang  \
# 691466  Prediction is reliable: True\nLanguage 1: name...   English
# 652860  Prediction is reliable: False\nLanguage 1: nam...  Galician
# 51738   Prediction is reliable: True\nLanguage 1: name...   English
# 475617  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 592884  Prediction is reliable: True\nLanguage 1: name...   Finnish
#
#         confidence
# 691466        93.0
# 652860        90.0
# 51738         92.0
# 475617        97.0
# 592884        96.0

# %%
#!jupyter nbextension enable --py widgetsnbextension
#!pip install modin[ray] --user

# %%
def return_single_translation(series,source_lang,translator_client):
    return translator_client.translate_text(Text=series,
            SourceLanguageCode="en",
            TargetLanguageCode="fi").get("TranslatedText")
    
def row_translator(row,**kwargs):
    """ Translates the original_categories feature if it is not Finnish.
    Univariate gives ENG to FIN translation, otherwise the most confident translation direction is used"""
    new_name = kwargs.get("new_name")
    translator_client = kwargs.get("translator_client")
    translation_mode = kwargs.get("translation_mode")
    old_name = kwargs.get("old_name")
    if row.loc["Text-lang"]=="Finnish":
        row.loc[new_name]  = row.loc[old_name]
    else:
        if translation_mode == "univariate":
            row.loc[new_name] = return_single_translation(series=row.original_categories,source_lang='en',translator_client=translator_client)
        else :
            row.loc[new_name] = return_single_translation(series=row.original_categories,source_lang='auto',translator_client=translator_client)
    return row

def translation_function(data,old_name="original_categories",new_prefix="trans"):
    import boto3
    from polyglot.detect import Detector
    new_name = f"{new_prefix}_{old_name}"
    translator_client = boto3.client("translate",region_name="us-east-1")
    kwargs = {"translator_client":translator_client,"new_name":new_name,\
             "translation_mode":"univariate","old_name":old_name}
    print("REACHED PROGRESS APPLY")
    tqdm.pandas(desc='PROGRESS>>>') 
    translated = data.progress_apply(row_translator,axis=1,**kwargs)
    translated = translated.drop(["poly_obj","brand"],axis=1)
    return translated,new_name

translated_,new_name = translation_function(data)
# Out:
# PROGRESS>>>:   0%|          | 0/200 [00:00<?, ?it/s]
# REACHED PROGRESS APPLY
# PROGRESS>>>:   1%|          | 2/200 [00:01<02:12,  1.49it/s]
#
#
#
#
#
#
# PROGRESS>>>:   2%|▏         | 3/200 [00:01<01:50,  1.79it/s]
#
#
#
#
#
#
# PROGRESS>>>:   2%|▏         | 4/200 [00:01<01:36,  2.03it/s]
#
#
#
#
#
#
# PROGRESS>>>:   2%|▎         | 5/200 [00:02<01:27,  2.24it/s]
#
#
#
#
#
#
# PROGRESS>>>:   4%|▍         | 8/200 [00:02<01:06,  2.88it/s]
#
#
#
#
#
#
# PROGRESS>>>:   6%|▌         | 12/200 [00:02<00:50,  3.74it/s]
#
#
#
#
#
#
# PROGRESS>>>:   6%|▋         | 13/200 [00:03<00:53,  3.48it/s]
#
#
#
#
#
#
# PROGRESS>>>:   7%|▋         | 14/200 [00:03<00:54,  3.44it/s]
#
#
#
#
#
#
# PROGRESS>>>:   8%|▊         | 15/200 [00:03<00:51,  3.57it/s]
#
#
#
#
#
#
# PROGRESS>>>:   9%|▉         | 18/200 [00:04<00:41,  4.39it/s]
#
#
#
#
#
#
# PROGRESS>>>:  10%|█         | 20/200 [00:04<00:37,  4.83it/s]
#
#
#
#
#
#
# PROGRESS>>>:  11%|█         | 22/200 [00:04<00:34,  5.12it/s]
#
#
#
#
#
#
# PROGRESS>>>:  14%|█▎        | 27/200 [00:05<00:29,  5.94it/s]
#
#
#
#
#
#
# PROGRESS>>>:  14%|█▍        | 29/200 [00:05<00:27,  6.29it/s]
#
#
#
#
#
#
# PROGRESS>>>:  15%|█▌        | 30/200 [00:06<00:42,  4.03it/s]
#
#
#
#
#
#
# PROGRESS>>>:  16%|█▋        | 33/200 [00:06<00:34,  4.82it/s]
#
#
#
#
#
#
# PROGRESS>>>:  17%|█▋        | 34/200 [00:06<00:41,  4.02it/s]
#
#
#
#
#
#
# PROGRESS>>>:  18%|█▊        | 35/200 [00:07<00:47,  3.45it/s]
#
#
#
#
#
#
# PROGRESS>>>:  20%|██        | 40/200 [00:07<00:36,  4.34it/s]
#
#
#
#
#
#
# PROGRESS>>>:  20%|██        | 41/200 [00:07<00:41,  3.88it/s]
#
#
#
#
#
#
# PROGRESS>>>:  22%|██▏       | 43/200 [00:08<00:35,  4.42it/s]
#
#
#
#
#
#
# PROGRESS>>>:  22%|██▏       | 44/200 [00:08<00:43,  3.61it/s]
#
#
#
#
#
#
# PROGRESS>>>:  22%|██▎       | 45/200 [00:08<00:44,  3.47it/s]
#
#
#
#
#
#
# PROGRESS>>>:  24%|██▎       | 47/200 [00:09<00:37,  4.13it/s]
#
#
#
#
#
#
# PROGRESS>>>:  24%|██▍       | 48/200 [00:09<00:38,  3.93it/s]
#
#
#
#
#
#
# PROGRESS>>>:  24%|██▍       | 49/200 [00:09<00:41,  3.67it/s]
#
#
#
#
#
#
# PROGRESS>>>:  25%|██▌       | 50/200 [00:10<00:40,  3.68it/s]
#
#
#
#
#
#
# PROGRESS>>>:  26%|██▌       | 52/200 [00:10<00:36,  4.01it/s]
#
#
#
#
#
#
# PROGRESS>>>:  26%|██▋       | 53/200 [00:10<00:38,  3.78it/s]
#
#
#
#
#
#
# PROGRESS>>>:  27%|██▋       | 54/200 [00:11<00:41,  3.56it/s]
#
#
#
#
#
#
# PROGRESS>>>:  28%|██▊       | 56/200 [00:11<00:33,  4.26it/s]
#
#
#
#
#
#
# PROGRESS>>>:  29%|██▉       | 58/200 [00:11<00:30,  4.71it/s]
#
#
#
#
#
#
# PROGRESS>>>:  30%|███       | 60/200 [00:12<00:27,  5.07it/s]
#
#
#
#
#
#
# PROGRESS>>>:  32%|███▎      | 65/200 [00:12<00:21,  6.33it/s]
#
#
#
#
#
#
# PROGRESS>>>:  34%|███▍      | 68/200 [00:12<00:20,  6.59it/s]
#
#
#
#
#
#
# PROGRESS>>>:  34%|███▍      | 69/200 [00:13<00:25,  5.13it/s]
#
#
#
#
#
#
# PROGRESS>>>:  35%|███▌      | 70/200 [00:13<00:29,  4.42it/s]
#
#
#
#
#
#
# PROGRESS>>>:  36%|███▌      | 71/200 [00:13<00:31,  4.09it/s]
#
#
#
#
#
#
# PROGRESS>>>:  36%|███▌      | 72/200 [00:13<00:33,  3.82it/s]
#
#
#
#
#
#
# PROGRESS>>>:  36%|███▋      | 73/200 [00:14<00:35,  3.58it/s]
#
#
#
#
#
#
# PROGRESS>>>:  38%|███▊      | 75/200 [00:14<00:30,  4.07it/s]
#
#
#
#
#
#
# PROGRESS>>>:  38%|███▊      | 77/200 [00:14<00:26,  4.62it/s]
#
#
#
#
#
#
# PROGRESS>>>:  40%|████      | 80/200 [00:15<00:22,  5.37it/s]
#
#
#
#
#
#
# PROGRESS>>>:  41%|████      | 82/200 [00:15<00:22,  5.29it/s]
#
#
#
#
#
#
# PROGRESS>>>:  42%|████▏     | 84/200 [00:16<00:21,  5.29it/s]
#
#
#
#
#
#
# PROGRESS>>>:  42%|████▎     | 85/200 [00:16<00:25,  4.45it/s]
#
#
#
#
#
#
# PROGRESS>>>:  43%|████▎     | 86/200 [00:16<00:29,  3.86it/s]
#
#
#
#
#
#
# PROGRESS>>>:  44%|████▎     | 87/200 [00:17<00:41,  2.71it/s]
#
#
#
#
#
#
# PROGRESS>>>:  44%|████▍     | 88/200 [00:17<00:38,  2.88it/s]
#
#
#
#
#
#
# PROGRESS>>>:  44%|████▍     | 89/200 [00:17<00:35,  3.13it/s]
#
#
#
#
#
#
# PROGRESS>>>:  46%|████▋     | 93/200 [00:18<00:26,  4.00it/s]
#
#
#
#
#
#
# PROGRESS>>>:  47%|████▋     | 94/200 [00:18<00:27,  3.91it/s]
#
#
#
#
#
#
# PROGRESS>>>:  50%|█████     | 100/200 [00:18<00:19,  5.17it/s]
#
#
#
#
#
#
# PROGRESS>>>:  50%|█████     | 101/200 [00:19<00:22,  4.34it/s]
#
#
#
#
#
#
# PROGRESS>>>:  51%|█████     | 102/200 [00:19<00:26,  3.72it/s]
#
#
#
#
#
#
# PROGRESS>>>:  52%|█████▏    | 104/200 [00:19<00:23,  4.17it/s]
#
#
#
#
#
#
# PROGRESS>>>:  53%|█████▎    | 106/200 [00:20<00:19,  4.73it/s]
#
#
#
#
#
#
# PROGRESS>>>:  55%|█████▍    | 109/200 [00:20<00:16,  5.48it/s]
#
#
#
#
#
#
# PROGRESS>>>:  55%|█████▌    | 110/200 [00:20<00:20,  4.32it/s]
#
#
#
#
#
#
# PROGRESS>>>:  57%|█████▋    | 114/200 [00:21<00:17,  4.86it/s]
#
#
#
#
#
#
# PROGRESS>>>:  58%|█████▊    | 116/200 [00:21<00:15,  5.26it/s]
#
#
#
#
#
#
# PROGRESS>>>:  59%|█████▉    | 118/200 [00:21<00:14,  5.76it/s]
#
#
#
#
#
#
# PROGRESS>>>:  60%|█████▉    | 119/200 [00:22<00:16,  5.06it/s]
#
#
#
#
#
#
# PROGRESS>>>:  60%|██████    | 120/200 [00:22<00:18,  4.26it/s]
#
#
#
#
#
#
# PROGRESS>>>:  61%|██████    | 122/200 [00:22<00:16,  4.81it/s]
#
#
#
#
#
#
# PROGRESS>>>:  62%|██████▏   | 124/200 [00:23<00:14,  5.39it/s]
#
#
#
#
#
#
# PROGRESS>>>:  62%|██████▎   | 125/200 [00:23<00:18,  4.10it/s]
#
#
#
#
#
#
# PROGRESS>>>:  63%|██████▎   | 126/200 [00:23<00:18,  4.09it/s]
#
#
#
#
#
#
# PROGRESS>>>:  64%|██████▍   | 129/200 [00:24<00:14,  4.78it/s]
#
#
#
#
#
#
# PROGRESS>>>:  65%|██████▌   | 130/200 [00:24<00:16,  4.30it/s]
#
#
#
#
#
#
# PROGRESS>>>:  66%|██████▌   | 132/200 [00:24<00:14,  4.74it/s]
#
#
#
#
#
#
# PROGRESS>>>:  67%|██████▋   | 134/200 [00:25<00:13,  4.84it/s]
#
#
#
#
#
#
# PROGRESS>>>:  68%|██████▊   | 136/200 [00:25<00:12,  5.22it/s]
#
#
#
#
#
#
# PROGRESS>>>:  68%|██████▊   | 137/200 [00:25<00:15,  4.04it/s]
#
#
#
#
#
#
# PROGRESS>>>:  69%|██████▉   | 138/200 [00:26<00:16,  3.79it/s]
#
#
#
#
#
#
# PROGRESS>>>:  70%|███████   | 141/200 [00:26<00:13,  4.47it/s]
#
#
#
#
#
#
# PROGRESS>>>:  71%|███████   | 142/200 [00:26<00:14,  4.02it/s]
#
#
#
#
#
#
# PROGRESS>>>:  72%|███████▏  | 144/200 [00:27<00:12,  4.58it/s]
#
#
#
#
#
#
# PROGRESS>>>:  74%|███████▎  | 147/200 [00:27<00:10,  5.26it/s]
#
#
#
#
#
#
# PROGRESS>>>:  74%|███████▍  | 148/200 [00:27<00:11,  4.37it/s]
#
#
#
#
#
#
# PROGRESS>>>:  74%|███████▍  | 149/200 [00:28<00:14,  3.58it/s]
#
#
#
#
#
#
# PROGRESS>>>:  75%|███████▌  | 150/200 [00:28<00:14,  3.50it/s]
#
#
#
#
#
#
# PROGRESS>>>:  76%|███████▌  | 151/200 [00:28<00:17,  2.79it/s]
#
#
#
#
#
#
# PROGRESS>>>:  76%|███████▋  | 153/200 [00:29<00:15,  3.04it/s]
#
#
#
#
#
#
# PROGRESS>>>:  78%|███████▊  | 155/200 [00:29<00:12,  3.54it/s]
#
#
#
#
#
#
# PROGRESS>>>:  78%|███████▊  | 156/200 [00:30<00:13,  3.31it/s]
#
#
#
#
#
#
# PROGRESS>>>:  78%|███████▊  | 157/200 [00:30<00:13,  3.25it/s]
#
#
#
#
#
#
# PROGRESS>>>:  80%|████████  | 160/200 [00:31<00:10,  3.75it/s]
#
#
#
#
#
#
# PROGRESS>>>:  80%|████████  | 161/200 [00:31<00:14,  2.72it/s]
#
#
#
#
#
#
# PROGRESS>>>:  82%|████████▏ | 164/200 [00:32<00:10,  3.35it/s]
#
#
#
#
#
#
# PROGRESS>>>:  83%|████████▎ | 166/200 [00:32<00:08,  3.92it/s]
# PROGRESS>>>:  84%|████████▍ | 169/200 [00:32<00:06,  4.72it/s]
#
#
#
#
#
#
# PROGRESS>>>:  86%|████████▋ | 173/200 [00:33<00:04,  5.60it/s]
#
#
#
#
#
#
# PROGRESS>>>:  87%|████████▋ | 174/200 [00:33<00:08,  3.24it/s]
#
#
#
#
#
#
# PROGRESS>>>:  88%|████████▊ | 176/200 [00:34<00:06,  3.64it/s]
#
#
#
#
#
#
# PROGRESS>>>:  89%|████████▉ | 178/200 [00:34<00:05,  3.72it/s]
#
#
#
#
#
#
# PROGRESS>>>:  90%|████████▉ | 179/200 [00:34<00:05,  3.61it/s]
#
#
#
#
#
#
# PROGRESS>>>:  91%|█████████ | 182/200 [00:35<00:04,  4.15it/s]
#
#
#
#
#
#
# PROGRESS>>>:  92%|█████████▏| 183/200 [00:35<00:04,  3.82it/s]
#
#
#
#
#
#
# PROGRESS>>>:  92%|█████████▏| 184/200 [00:36<00:05,  3.13it/s]
#
#
#
#
#
#
# PROGRESS>>>:  92%|█████████▎| 185/200 [00:36<00:06,  2.41it/s]
#
#
#
#
#
#
# PROGRESS>>>:  93%|█████████▎| 186/200 [00:37<00:05,  2.43it/s]
#
#
#
#
#
#
# PROGRESS>>>:  94%|█████████▍| 188/200 [00:37<00:04,  2.61it/s]
#
#
#
#
#
#
# PROGRESS>>>:  94%|█████████▍| 189/200 [00:38<00:04,  2.61it/s]
#
#
#
#
#
#
# PROGRESS>>>:  96%|█████████▌| 191/200 [00:38<00:02,  3.20it/s]
#
#
#
#
#
#
# PROGRESS>>>:  96%|█████████▌| 192/200 [00:38<00:02,  3.34it/s]
#
#
#
#
#
#
# PROGRESS>>>:  98%|█████████▊| 195/200 [00:39<00:01,  4.17it/s]
#
#
#
#
#
#
# PROGRESS>>>:  98%|█████████▊| 196/200 [00:39<00:01,  3.66it/s]
#
#
#
#
#
#
# PROGRESS>>>:  98%|█████████▊| 197/200 [00:39<00:00,  3.43it/s]
#
#
#
#
#
#
# PROGRESS>>>:  99%|█████████▉| 198/200 [00:40<00:00,  3.18it/s]
#
#
#
#
#
#
# PROGRESS>>>: 100%|█████████▉| 199/200 [00:40<00:00,  2.50it/s]
#
#
#
#
#
#
# PROGRESS>>>: 100%|██████████| 200/200 [00:41<00:00,  4.82it/s]

# %%
translated_.head()
# Out:
#                                                      name  \
# 691466                   Leggings Leggingsit Musta Lindex
# 652860  Polo Shirts Lyhythihainen Poolopaita Harmaa Es...
# 51738                                   Womens Ultra Flex
# 475617  Iron Gym® Exercise & Yoga Mat With Carry Strap...
# 592884       Happy Holly Ida Suede Look Skirt Beige 40/42
#
#                                               description  \
# 691466                                            Lindex.
# 652860                          Esprit Casual Polo Shirts
# 51738                          Skechers Womens Ultra Flex
# 475617  Iron Gym® Exercise & Yoga Mat with Carry Strap...
# 592884  HAPPY HOLLY tyylikäs kynähame mokkajäljitelmää...
#
#                                original_categories  \
# 691466                               Kids|Leggings
# 652860                                   Men|Polos
# 51738                                  Women|Shoes
# 475617  Varusteet & Tarvikkeet|Välineet|Joogamatot
# 592884                  Vaatteet|Hameet|Midihameet
#
#                                             internal_tree          brand  \
# 691466                       Children | Vaatteet | Housut         Lindex
# 652860      Fashion | Vaatteet | Miehet | Paidat | Poolot  Esprit Casual
# 51738                           Fashion | Kengät | Naiset       Skechers
# 475617       Fitness | Treenivarusteet | Jooga ja pilates       Iron Gym
# 592884  Fashion | Vaatteet | Naiset | Hameet | Midihameet    Happy Holly
#
#                                                  poly_obj Text-lang  \
# 691466  Prediction is reliable: True\nLanguage 1: name...   English
# 652860  Prediction is reliable: False\nLanguage 1: nam...  Galician
# 51738   Prediction is reliable: True\nLanguage 1: name...   English
# 475617  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 592884  Prediction is reliable: True\nLanguage 1: name...   Finnish
#
#         confidence                   trans_original_categories
# 691466        93.0                           Lapset|Leggingsit
# 652860        90.0                                Miehet|Polos
# 51738         92.0                               Naiset|Kengät
# 475617        97.0  Varusteet & Tarvikkeet|Välineet|Joogamatot
# 592884        96.0                  Vaatteet|Hameet|Midihameet

# %%
import re
""" Run the translations only on unique categories and later you can use that dictionary to look up translations for any data"""
def post_process_features(data,name,mode="translationcheck"):
    """ Add regex substitutions here"""
    #data = data.reset_index(drop=True)
    data.trans_original_categories = data.trans_original_categories.\
    replace("Male","Miehet",regex=False).\
    replace("Female","Naiset",regex=False)
    
    
    if mode == "normal":
        sel = data.loc[:,["trans_original_categories", "name","description","internal_tree"]]
       
    elif mode == "translationcheck":
        sel = data.loc[:,["trans_original_categories","original_categories"]]
    filename = os.path.join("..","data",name + ".csv")
    sel.to_csv(filename)
    return sel
             
#d = post_process_features(data=translated_,name="translations_post")

#re.findall("[Ff]emale",str(d.trans_original_categories.values))
# Out:
# ['Female', 'Female']

# %%
#filename = os.path.join("..","data","translationcheck" + ".csv")
d.trans_original_categories.values
#!cat
# Out:
# array(['Lapset|Leggingsit', 'Miehet|Polos', 'Naiset|Kengät',
#        'Varusteet & Tarvikkeet|Välineet|Joogamatot',
#        'Vaatteet|Hameet|Midihameet', 'Naiset|Kengät',
#        'Naisten|Kengät|Sandaalit', 'Vaatteet',
#        'Huonekalut|Huonekalujen Tarvikkeet|Huonekalujen Verhoilu',
#        'Naiset|T-paidat & Topit', 'Naiset|Kauneus Naiset', 'Naiset|Mekot',
#        'Miehet|T-paidat', 'Kauneudenhoito', 'Kellot|Naisten Kellot',
#        'Ihonhoito', 'Miesten|Kengät|Juoksukengät',
#        'Lapset|Päällysvaatteet', 'Naisten|Kengät|Matalavartiset Tennarit',
#        'Naiset|Housut', 'Kellot|Miesten Kellot', 'Kellot|Miesten Kellot',
#        'Vaatteet', 'Vaatteet|Takit|Takkeja', 'Naiset|Kauneus Naiset',
#        'Tuotemerkit/Baci|Asut/Rooli- ja naamiaisasut', 'Naiset|Hameet',
#        'Naisten Wear|Sisäpohjat|Shortsit',
#        'Miesten|Kengät|Matalavartiset Tennarit', 'Kengät|Lenkkarit',
#        'Ale Ale Shortsit', 'Nainen|Kengät|Flats|Sandaalit',
#        'Nainen|Kauneus|Meikit|Primers', 'Vaatteet', 'Kauneudenhoito',
#        'Female|Vaatteet|Hameet|Midihameet',
#        'Seksilelut|Tarvikkeet|Säilytystarvikkeet', 'Ihonhoito',
#        'Miehet|Neuleet', 'Female|Kauneus|Kasvojenhoito|Kasvonaamiot',
#        'Miehet|T-paidat', 'Naiset|Laukut', 'Naiset|Kengät', 'Vaatteet',
#        'Naiset|Laukut', 'Miehet|Lisävarusteet', 'Naiset|Kengät', 'Meikki',
#        'Vaatteet|Takit|Takkeja', 'Naiset|Mekot', 'Naiset|Uimapuvut',
#        'Chinot', 'Ale Ale Alusvaatteet', 'Naiset|Laukut',
#        'Male|Vaatteita-Miehille|Vaatteet|Kauluspaidat',
#        'Naisten parfyymi', 'Asusteet', 'Naiset|Kengät',
#        'Naisten|Vaatteet|Neuleet / Villatakit', 'Yläosat|Tunika',
#        'Vaatteet', 'Kellot|Miesten Kellot', 'Naiset|Jumpsuits',
#        'Kellot|Miesten Kellot', 'Hiustenhoito', 'Koiralelu',
#        'Naiset|Päällysvaatteet', 'Naiset|Mekot', 'Miehet|Päällysvaatteet',
#        'Lapset | T-paidat', 'Meikit', 'Korkokengät Ja Saappaat',
#        'Naiset|Mekot', 'Miesten|Vaatteet|Lyhythihainen T-Paita',
#        'Lapset|Mekot & Hameet', 'Laukut|Koululaukku',
#        'Vaatteet|Hameet|Minihameet', 'Naiset|Päällysvaatteet',
#        'Sisustus|Kynttilänjalat & Kynttilälyhdyt|Kynttilälyhdyt',
#        'Naiset|T-paidat & Topit', 'Vaatteet|Mekot|Maksimekot',
#        'Naiset|Päällysvaatteet', 'Naiset|Hameet', 'Naiset|Kauneus Naiset',
#        'Miehet|Päällysvaatteet', 'Lapset |Kengät', 'Naiset|Hameet',
#        'Kauneudenhoito', 'Sisävalaisimet', 'Vaatteet',
#        'Naiset|Päällysvaatteet', 'Miehet|Kengät',
#        'Vaatteet|Puserot & Kauluspaidat|Puserot & Tunikat',
#        'Huonekalut|Säilytys & Hyllyt|Senkit & Sivupöydät',
#        'Huonekalut|Tuolit & Jakkarat|Tuolit', 'Vaatteet', 'Vaatteet',
#        'Lapset|Päällysvaatteet', 'Meikki', 'Naiset|Päällysvaatteet',
#        'Naisten|Kengät|Kangassandaalit', 'Naisten parfyymi',
#        'Ale Ale Farkut Ja Housut', 'Naisten parfyymi',
#        'Tuoksut > Hajuvedet > Muut Tuoksut',
#        'Seksilelut|Anaaliseksi|Anustapit ja -sauvat|Silikoniset anustapit',
#        'Miehet|Neuleet', '- Ole', 'Vaatteet',
#        'Naisten|Kengät|Matalavartiset Tennarit',
#        'Grooming|Hiusten Hoito Ja Muotoilu|Muotoilu',
#        'Kissat, Kissan Märkäruoka, ★ Cosma, Cosma Thai',
#        'Koti|Puutarhakalusteet|Terassipöydät|Kahvilapöydät', 'Meikki',
#        'Naisten|Kengät|Bootsit', 'Ihonhoito', 'Naiset|Mekot',
#        'Naiset|T-paidat & Topit', 'Hiustenhoito', 'Naiset|Kauneus Naiset',
#        'Vaatteet|Mekot|Midimekot', 'Miehet|Alusvaatteet',
#        'Lapset |Kengät', 'Naiset|Lisävarusteet', 'Kellot|Naisten Kellot',
#        'Urheiluvaatteet|Urheiluvaatteet Miehille|Asusteet',
#        'Lapset|Päällysvaatteet', 'Naiset|Puserot', 'Kauneudenhoito',
#        'Miehet|Housut', 'Male|Vaatteita-Miehille|Vaatteet|Puserot',
#        'Miehet|Kengät',
#        'Sisustus|Kynttilänjalat & Kynttilälyhdyt|Kynttilälyhdyt',
#        'Lapset | T-paidat', 'Miehet|Puvut & bleiserit', 'Miehet|Paidat',
#        'Naisten|Kengät|Korkeavartiset Tennarit',
#        'Vaatteet|Alusvaatteet & Univaatteet|Aamutakit',
#        'Miehet|Urheiluhousut (Main) (Urheilumerkit)',
#        'Naiset|Kauneus Naiset', 'Lasten|Poikien|Kengät|Bootsit',
#        'Naiset|Puserot', 'Riippuvalaisimet', 'Seksilelut Seksikauppa',
#        'Lapset|Farkut', 'Miehet|Paidat', 'Lapset|Uimapuvut',
#        'Naiset|Farkut', 'Naiset|Puserot',
#        'Male|Vaatteita-Miehille|Vaatteet|Kauluspaidat',
#        'Pimeä|Bondage|Sitomisleikit', 'Kengät', 'Naisten parfyymi',
#        'Lapset|Leggingsit', 'Miehet|Kengät',
#        'Meikit > Huulet > Huulipuna',
#        'Canvas-Taulut Mallisto Ja Kuvagalleria', 'Naiset|Hameet',
#        'Naiset|Kengät', 'Miesten Ihonhoito', 'Ale Ale Neuleet',
#        'Naiset|Kauneus Naiset', 'Kellot|Miesten Kellot', 'Meikit',
#        'Lasten|Tyttöjen|Kengät|Matalavartiset Tennarit',
#        'Kellot|Miesten Kellot', 'Naiset|Päällysvaatteet',
#        'Vaatteet|Farkut|Stretchfarkut',
#        'Koirat, Koiran Puruherkut, Purina, Proplan',
#        'Vaatteet|T-Paidat|Yksiväriset T-Paidat', 'Meikki',
#        'Lapset|Mekot & Hameet', 'Meikki > Kasvot > Meikkivoiteet',
#        'Lapset|Mekot & Hameet', 'Kellot|Miesten Kellot',
#        'Naisten parfyymi', 'Naiset|Alusvaatteet',
#        'Koti|Puutarhakalusteet|Pehmusteet|Baden-Baden pehmusteet',
#        'Lisäravinteet|Patukat|Proteiinipatukat',
#        'Miehet|Paidat & Hupparit', 'Lapset|Lisävarusteet', 'Naiset|Mekot',
#        'Nainen|Vaatteet|Paidat & Topit|Topit', 'Miehet|Kengät',
#        'MIEHET|Hiukset|Parta ja viikset', 'Printti-T-Paidat',
#        'Naisten parfyymi', 'Kellot|Miesten Kellot', 'Naiset|Kengät',
#        'Lapset | T-paidat', 'Naisten Tuoksut', 'Naisten|Vaatteet|Paita',
#        'Naiset|Kauneus Naiset', 'Naiset|Hupparit & Hupparit',
#        'Naiset|Kauneus Naiset', 'Vaatteet|Vaatteet|Housut',
#        'Naiset|Hameet', 'Lapset|Hupparit & Hupparit',
#        'IHONHOITO|Kasvot|Ihonhoitotuotteet|Anti-age-tuotteet',
#        'Naiset|Farkut'], dtype=object)

# %%
# %automagic 1
#%cat ../data/translationcheck.csv
# Out:
# Automagic is ON, % prefix IS NOT needed for line magics.
# cat: ../data/translationcheck.csv: No such file or directory

# %%
#df.Text = df.original_categories.astype(str)
# basically we need to apply this function to every row in the dataframe and later speed it up
# translation_function is used in the next code cell, so make sure that you use the
# apply + iterrows combination in the right way!
# translations = []
# or row in df.head().itertuples():
#    #if row.confidence > 90:
#    out = translator_client.translate_text(Text=row.original_categories,
#            SourceLanguageCode='en',
#            TargetLanguageCode='fi').get("TranslatedText")
#    translations.append(out)
#    #tuples = pd.concat([tuples,pd.DataFrame.from_dict(out.get("TranslatedText"))],axis=0)


import icu


def row_translator(row,**kwargs):
    print()
    translator_client = kwargs.get("translator_client")
    if row.loc['Text-LangConfidence'] > 90:
        row.loc['translated'] = translator_client.translate_text(Text=row.loc['original_categories'],
                SourceLanguageCode='en',
                TargetLanguageCode='fi').get("TranslatedText")
    else : 
        row.loc['translated'] = translator_client.translate_text(Text=row.loc['original_categories'],
                SourceLanguageCode='auto',
                TargetLanguageCode='fi').get("TranslatedText")
    return row

def translation_function(data,old_name="original_categories"):
    import boto3
    from polyglot.detect import Detector
    translator_client = boto3.client('translate',region_name='us-east-1')
    kwargs = {'translator_client':translator_client,'new_name':f"trans_{old_name}"}
    translated = data.head().apply(row_translator,axis=1,**kwargs)
    return translated
    
        

translated = translation_function(df)

# %%
translated.head()
# Out:
#                               original_categories  \
# 0  Tuotemerkit/Jimmyjane|Terveystuotteet/Kuukuppi
# 1  Tuotemerkit/Jimmyjane|Terveystuotteet/Kuukuppi
# 2                      Kondomit|Tuotemerkit/Durex
# 3                      Kondomit|Tuotemerkit/Durex
# 4                      Kondomit|Tuotemerkit/Durex
#
#                          internal_tree  \
# 0             Health | Intiimituotteet
# 1             Health | Intiimituotteet
# 2  Health | Intiimituotteet | Kondomit
# 3  Health | Intiimituotteet | Kondomit
# 4  Health | Intiimituotteet | Kondomit
#
#                                             poly_obj Text-lang  \
# 0  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 1  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 2  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 3  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 4  Prediction is reliable: True\nLanguage 1: name...   Finnish
#
#    Text-LangConfidence  confidence  \
# 0                 97.0        97.0
# 1                 97.0        97.0
# 2                 96.0        96.0
# 3                 96.0        96.0
# 4                 96.0        96.0
#
#                                      translated
# 0  Tuotetiedot/Jimmyjane|Terveystuotteet/Kuuppi
# 1  Tuotetiedot/Jimmyjane|Terveystuotteet/Kuuppi
# 2                     Kondomit|Tuotemerki/Durex
# 3                     Kondomit|Tuotemerki/Durex
# 4                     Kondomit|Tuotemerki/Durex

# %%
for index,row in df.iterrows():
    row.loc['translated'] = translator_client.translate_text(Text=row.loc['original_categories'],
                    SourceLanguageCode='en',
                    TargetLanguageCode='fi').get("TranslatedText")

# %%
df.columns
# Out:
# Index(['original_categories', 'internal_tree', 'poly_obj', 'Text-lang',
#        'Text-LangConfidence'],
#       dtype='object')

# %%
import icu
df.Text = df.Text.astype(str)
df['poly_obj'] = df.Text.apply(lambda x: Detector(x, quiet=True))
df['Text-lang'] = df['poly_obj'].apply(lambda x: icu.Locale.getDisplayName(x.language.locale))
df['Text-LangConfidence'] = df['poly_obj'].apply( lambda x: x.language.confidence)

def translation_function(data):
    import boto3
    from polyglot.detect import Detector
    translator_client = boto3.client('translate',region_name='us-east-1')
    if data['Text-LangConfidence'] > 90:
        response = translator_client.translate_text(Text=data['original_categories'],
                SourceLanguageCode='en',
                TargetLanguageCode='fi')
    else : 
        response = translator_client.translate_text(Text=data['original_categories'],
                SourceLanguageCode='auto',
                TargetLanguageCode='fi')
    return response.get("TranslatedText")

def check_confidence_and_translate(df,col_to_translate):
    flag = 0
    selected_series = df.loc[:,col_to_translate]
    df['poly_obj'] = selected_series.apply(lambda x: Detector(x, quiet=True))
    df['Text-LangConfidence'] = df['poly_obj'].apply( lambda x: x.language.confidence)
    new_col_name = f"translated_{col_to_translate}""
    df[new_col_name] = df.apply(translation_function)
    if language.confidence > 90.0 and language.code == 'en':
                flag = 1
                response = translator_client.translate_text(Text=a,
                SourceLanguageCode='en',
                TargetLanguageCode='fi')
                print(response.get("TranslatedText"))
                break

# %%
flag = 0
for language in Detector(a).languages:
        if language.confidence > 90.0 and language.code == 'en':
            flag = 1
            response = translator_client.translate_text(Text=a,
            SourceLanguageCode='en',
            TargetLanguageCode='fi')
            print(response.get("TranslatedText"))
            break
            
if flag == 0:
    response = translator_client.translate_text(Text=a,
    SourceLanguageCode='auto',
    TargetLanguageCode='fi')
    print("English not detected with sufficient confidence, reverting to auto-translate")
    print(response.get("TranslatedText"))
# Out:
#                               original_categories  \
# 0  Tuotemerkit/Jimmyjane|Terveystuotteet/Kuukuppi
# 1  Tuotemerkit/Jimmyjane|Terveystuotteet/Kuukuppi
# 2                      Kondomit|Tuotemerkit/Durex
# 3                      Kondomit|Tuotemerkit/Durex
# 4                      Kondomit|Tuotemerkit/Durex
#
#                          internal_tree  \
# 0             Health | Intiimituotteet
# 1             Health | Intiimituotteet
# 2  Health | Intiimituotteet | Kondomit
# 3  Health | Intiimituotteet | Kondomit
# 4  Health | Intiimituotteet | Kondomit
#
#                                             poly_obj Text-lang  \
# 0  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 1  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 2  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 3  Prediction is reliable: True\nLanguage 1: name...   Finnish
# 4  Prediction is reliable: True\nLanguage 1: name...   Finnish
#
#    Text-LangConfidence
# 0                 97.0
# 1                 97.0
# 2                 96.0
# 3                 96.0
# 4                 96.0

# %%
detected_languages = Detector(a).languages
# you can access detected_languages as Pandas dataFrame api
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9fb4e2441b84> in <module>
#       1 detected_languages = Detector(a).languages
#       2 # you can access detected_languages as a dictionary
# ----> 3 detected_languages.get("code")
#
# AttributeError: 'list' object has no attribute 'get'
